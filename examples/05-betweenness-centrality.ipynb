# %% [markdown]
# ![superblockify_logo.png](attachment:8a415f1d-cfcf-4c3e-9078-13167177082e.png)

# %% [markdown]
# More info: [superblockify.city](https://superblockify.city)

# %% [markdown]
# # Betweenness centrality
#
# This notebook calculate betweenness centrality of a street network, to be used in partitioning approaches and for evaluation of nodes and edges. Because we need to respect the
# [Partition Requirements](./partition_requirements), we need to calculate
# betweenness centrality in a special way, using the shortest paths we calculated in
# [Restricted Distance Calculation](./dist_calc_restricted).
# We will show this conceptually using pair-wise dependencies, as shown by Brandes (2001),
# and modified from {external+networkx:mod}`networkx.algorithms.centrality.betweenness`.
#
# ### Pair-Wise Dependencies
# "... the cubic number of pair-wise dependencies
# $\delta(s, t \mid v)=\sigma(s, t \mid v) / \sigma(s, t)$
# can be aggregated without computing all of the explicitly."
#
# One-sided dependencies:
# $\delta(s \mid v)=\sum_{t \in V} \delta(s, t \mid v)$
#
# (see [Brandes, 2008](https://doi.org/10.1016/j.socnet.2007.11.001))
#
# We can span up trees for each row in the predecessor matrix, symbolizing the
# shortest paths from the source node to all other nodes. Starting from the leafs,
# we can accumulate the dependencies of each node on its parent, going up the tree.
# This way, we can accumulate the dependencies of all nodes (and edges!) on the way.
#
# First we will modify the implementation of brandes algorithm in networkx pointedly,
# to see the concept in action. Then, we will simplify it to our needs. Lastly we
# compare the performance.
#
# ## Modified implementation
#
# Special part: Replace single-source shortest-path step discovery with
# given predecessor and distance matrices to stipulate the shortest paths.
# Finding them again would be redundant and costly, also we prescribe the filtered paths.

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
from networkx.algorithms.centrality.betweenness import \
    _single_source_dijkstra_path_basic, \
    _rescale
from scipy.sparse.csgraph import dijkstra

from superblockify.metrics.distances import shortest_paths_restricted
# Out:
# 2026-03-23 10:55:29,468 |     INFO | __init__.py:11 | superblockify version 1.0.2

# %% [markdown]
# Let's use the same graph as in the second example of
# [Restricted Distance Calculation](./dist_calc_restricted).

# %%
# Create planar graph, similar to a street network
G = nx.MultiDiGraph(nx.Graph(
    [
        (10, 11, {"weight": 1}),
        (11, 12, {"weight": 1}),
        (12, 13, {"weight": 1}),
        (13, 0, {"weight": 1.5}),
        (13, 14, {"weight": 1}),
        (14, 0, {"weight": 1}),
        (0, 10, {"weight": 1}),
        (0, 1, {"weight": 1}),
        (10, 1, {"weight": 1}),
        (1, 2, {"weight": 1}),
        (2, 3, {"weight": 1}),
        (3, 4, {"weight": 1.5}),
        (4, 5, {"weight": 1}),
        (5, 9, {"weight": 1}),
        (5, 6, {"weight": 1}),
        (7, 2, {"weight": 1}),
        (8, 7, {"weight": 0.5}),
        (7, 1, {"weight": 1}),
        (8, 9, {"weight": 0.7}),
        (6, 9, {"weight": 1}),
        (8, 4, {"weight": 1}),
        (9, 1, {"weight": 1}),
        (0, 18, {"weight": 0.4}),
        (18, 2, {"weight": 0.4}),
        (6, 15, {"weight": 0.8}),
        (15, 16, {"weight": 1}),
        (16, 17, {"weight": 1}),
        (17, 6, {"weight": 1}),
    ]
))
G.add_node(19)  # isolated node
# Delete directed edges (1, 9), (6, 17), (10, 1)
G.remove_edges_from([(1, 9), (6, 17), (10, 1)])
# Add longer edge 0 -> 13
G.add_edge(0, 13, weight=G[0][13][0]["weight"] * 2)

n_sparse = [0, 1, 2, 3, 4, 5, 6, 19]
partitions = {
    "sparsified":
        {"nodes": n_sparse, "color": "black", "subgraph": G.subgraph(n_sparse)},
    "G_r": {"nodes": [7, 8, 9], "color": "crimson"},
    "G_g": {"nodes": [10, 11, 12, 13, 14], "color": "mediumseagreen"},
    "G_b": {"nodes": [15, 16, 17], "color": "dodgerblue"},
    "G_o": {"nodes": [18], "color": "darkorange"},
}
for name, part in partitions.items():
    if "subgraph" not in part:
        # subgraph for all edges from or to nodes in partition
        part["subgraph"] = G.edge_subgraph(
            # [(u, v) for u, v in G.edges if u in part["nodes"] or v in part["nodes"]]
            [e for e in G.edges if e[0] in part["nodes"] or e[1] in part["nodes"]]
        )
    part["nodelist"] = part["subgraph"].nodes
    for node in part["nodes"]:
        G.nodes[node]["partition"] = part["color"]

nx.draw(G, with_labels=True, node_color=[G.nodes[n]["partition"] for n in G
        .nodes],
        font_color="white",
        pos=nx.kamada_kawai_layout(G),
        ax=plt.figure(figsize=(8, 5)).gca(),
        connectionstyle="arc3,rad=0.1",
        )

# %% [markdown]
# First, calculate distance and predecessor matrices for the whole graph. Once plain, once
# restricted to the sparsified nodes.

# %%
node_order = list(range(len(G.nodes)))
G_sparse = nx.to_scipy_sparse_array(G, nodelist=node_order, weight="weight")
G_sparse.indices, G_sparse.indptr = G_sparse.indices.astype(
    np.int32), G_sparse.indptr.astype(np.int32)
dist, pred = dijkstra(G_sparse, directed=True, indices=node_order,
                      return_predecessors=True)
dist_restr, pred_restr = shortest_paths_restricted(G, partitions, weight="weight",
                                                   node_order=node_order)

# %% [markdown]
# Now we want to calculate node and edge betweenness centrality for the whole graph, using
#  three methods
# - a new dijkstra pass, just as in
#   {py:func}`networkx.edge_betweenness_centrality`
# - with given distance and predecessor matrices
# - with restricted distance and predecessor matrices

# %%
# Helper function to visualize the predecessor graph
def plot_graph_from_predecessors(P, s, method_name):
    """Plot tree graph from predecessors dict P, with source s highlighted."""
    G_pred = nx.DiGraph()
    # value pf P is list of predecessors
    G_pred.add_edges_from(
        [(u, v) for v, u_list in P.items() for u in u_list]
    )
    axe = plt.figure(figsize=(8, 5)).gca()
    nx.draw_networkx(
        G_pred, with_labels=True,
        node_color=[G.nodes[n]["partition"] if s != n else "pink"
                    for n in G_pred.nodes],
        font_color="white",
        pos=nx.kamada_kawai_layout(G),
        ax=axe,
    )
    # Add title
    axe.set_title(f"Predecessor graph for {method_name} from node {s}")

# %% [markdown]
# A function that generates the same output as the NetworkX internal function
# {external+networkx:func}`networkx.algorithms.centrality.betweenness._single_source_dijkstra_path_basic`,
# so we can swap it out.

# %%
from numpy import argsort


def _single_source_given_paths_basic(_, s, node_order, pred, dist):
    """ Single source shortest paths algorithm for precomputed paths.

    Parameters
    ----------
    _ : np.array
        Graph. For compatibility with other functions.
    s : int
        Source node id.
    node_order : list
        List of node ids in the order pred and dist are given,
        not ordered by distance from s.
    pred : np.array
        Predecessor matrix for source node s.
    dist : np.array
        Distance matrix for source node s.

    Returns
    -------
    S : list
        List of nodes in order of non-decreasing distance from s.
    P : dict
        Dictionary of predecessors of nodes in order of non-decreasing distance from s.
    sigma : dict
        Dictionary of number of shortest paths to nodes.
    D : dict
        Dictionary of distances to nodes.

    Notes
    -----
    Modified from :mod:`networkx.algorithms.centrality.betweenness`.

    Does not include endpoints.
    """
    # Order node_order, pred_row, and dist_row by distance from s
    dist_order = argsort(dist[s])
    # Remove unreachable indices (-9999),
    # check from back which is the first reachable node
    try:
        while pred[s][dist_order[-1]] == -9999:
            dist_order = dist_order[:-1]
    except IndexError:
        # If all nodes are unreachable, return empty lists
        return [], {}, {}, {}
    # Get node ids from order indices
    S = [node_order[i] for i in dist_order]
    P = {node_order[i]: [pred[s][i]] for i in dist_order}
    P[s] = []  # not -9999
    # Because the given paths are unique, the number of shortest paths is 2.0
    sigma = dict.fromkeys(S, 2.0)
    D = {node_order[i]: dist[s][i] for i in dist_order}
    return S, P, sigma, D

# %% [markdown]
# To calculate not only node betweenness, but also edge betweenness, as well as length and
# linearly scaled betweenness, we need to modify the function. This function returns
# the different kinds of betweenness in a dict. For the edge $t = 17$, we plot the
# predecessor graphs for the three methods.

# %%
t = 17


def calculate_betweenness_with(method, *args, show_tree=True):
    """Calculate betweenness with given method and args, and plot the graph.
    Show tree graph of predecessors for node ``t``."""
    betweenness = dict.fromkeys(G, 0.0)
    betweenness_len = betweenness.copy()  # Length scaled betweenness
    betweenness_lin = betweenness.copy()  # Linear scaled betweenness
    betweenness_edge = betweenness.copy()
    betweenness_edge.update(dict.fromkeys(G.edges(), 0.0))
    betweenness_edge_len = betweenness_edge.copy()
    betweenness_edge_lin = betweenness_edge.copy()
    # b[v]=0 for v in G and b[e]=0 for e in G.edges
    # Loop over nodes to collect betweenness using pair-wise dependencies
    for s in G:
        S, P, sigma, D = method(G, s, *args)
        # betweenness, _ = _accumulate_basic(betweenness, S.copy(), P, sigma, s)
        # betweenness_edge = _accumulate_edges(betweenness_edge, S.copy(), P, sigma, s)
        delta = dict.fromkeys(S, 0)
        delta_len = delta.copy()
        while S:
            w = S.pop()
            coeff = (1 + delta[w]) / sigma[w]
            coeff_len = (1 / D[w] + delta[w]) / sigma[w] if D[w] != 0 else 0
            for v in P[w]:
                c = sigma[v] * coeff
                c_len = sigma[v] * coeff_len
                if (v, w) not in betweenness_edge:
                    betweenness_edge[(w, v)] += c
                    betweenness_edge_len[(w, v)] += c_len
                    betweenness_edge_lin[(w, v)] += D[w] * c_len
                else:
                    betweenness_edge[(v, w)] += c
                    betweenness_edge_len[(v, w)] += c_len
                    betweenness_edge_lin[(v, w)] += D[w] * c_len
                delta[v] += c
                delta_len[v] += sigma[v] * coeff_len
            if w != s:
                betweenness[w] += delta[w]
                betweenness_len[w] += delta_len[w]
                betweenness_lin[w] += D[w] * delta_len[w]
        if s == t and show_tree:
            plot_graph_from_predecessors(P, s, method.__name__)
    # Normalize betweenness values
    betweenness = _rescale(betweenness, len(G), normalized=True, directed=True)
    betweenness_len = _rescale(betweenness_len, len(G), normalized=True, directed=True)
    betweenness_lin = _rescale(betweenness_lin, len(G), normalized=True, directed=True)
    for n in G:  # Remove nodes
        del betweenness_edge[n]
        del betweenness_edge_len[n]
        del betweenness_edge_lin[n]
    betweenness_edge = _rescale(betweenness_edge, len(G), normalized=True,
                                  directed=True, endpoints=True)
    betweenness_edge_len = _rescale(betweenness_edge_len, len(G), normalized=True,
                                      directed=True, endpoints=True)
    betweenness_edge_lin = _rescale(betweenness_edge_lin, len(G), normalized=True,
                                      directed=True, endpoints=True)
    return {
        "Node": betweenness,
        "Edge": betweenness_edge,
        "Node_len": betweenness_len,
        "Edge_len": betweenness_edge_len,
        "Node_lin": betweenness_lin,
        "Edge_lin": betweenness_edge_lin
    }


cb = calculate_betweenness_with(_single_source_dijkstra_path_basic, "weight")
cb_paths = calculate_betweenness_with(_single_source_given_paths_basic,
                                      node_order, pred, dist)
cb_restr = calculate_betweenness_with(_single_source_given_paths_basic,
                                      node_order, pred_restr, dist_restr)

# %% [markdown]
# The most obvious difference between the predecessor graphs is that the paths to node 17
# go through the sparsified, black nodes. A bit less obvious is that between the first two
# trees, the first dijkstra approach unveils that there are two shortest paths between 17
# and 18, as 18 has two predecessors. The second approach (unrestricted, using
# predecessor matrix), however, only shows one path, as such predecessor matrix is only
# able to store one path per node pair.
#
# The comparison between the node betweenness shows the same. The first approaches yield
# mostly the same results, but 2 and 0 as predecessors of 18 differ. The maximal
# difference is just $1.1\%$.

# %%
display(pd.DataFrame({
    ("", "C_B"): cb["Node"], ("", "C_B_paths"): cb_paths["Node"],
    ("", "C_B_restr"): cb_restr["Node"],
    ("Len scales", "C_B"): cb["Node_len"],
    ("Len scales", "C_B_paths"): cb_paths["Node_len"],
    ("Len scales", "C_B_restr"): cb_restr["Node_len"],
    ("Lin scales", "C_B"): cb["Node_lin"],
    ("Lin scales", "C_B_paths"): cb_paths["Node_lin"],
    ("Lin scales", "C_B_restr"): cb_restr["Node_lin"]
}
).sort_values(by=[("", "C_B")], ascending=False)
        .style.background_gradient(cmap="Blues", axis=None)
        .format(precision=3)
        .map_index(lambda x: f"color: {G.nodes[x]['partition']}" if x in G
                   .nodes else ""). \
        set_table_attributes('style="font-size: 12px"'),
        )
# Out:
# <style type="text/css">
# #T_f2fab_row0_col0, #T_f2fab_row0_col1, #T_f2fab_row1_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_f2fab_row0_col2, #T_f2fab_row0_col8, #T_f2fab_row5_col5, #T_f2fab_row10_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_f2fab_row0_col3, #T_f2fab_row0_col4, #T_f2fab_row12_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_f2fab_row0_col5, #T_f2fab_row10_col3, #T_f2fab_row10_col4, #T_f2fab_row10_col5, #T_f2fab_row11_col0, #T_f2fab_row11_col1, #T_f2fab_row11_col2, #T_f2fab_row12_col0, #T_f2fab_row12_col1, #T_f2fab_row13_col2, #T_f2fab_row17_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f2fab_row0_col6, #T_f2fab_row0_col7 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_f2fab_row1_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_f2fab_row1_col2, #T_f2fab_row7_col6, #T_f2fab_row7_col7 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_f2fab_row1_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_f2fab_row1_col4, #T_f2fab_row4_col0, #T_f2fab_row4_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_f2fab_row1_col5, #T_f2fab_row6_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_f2fab_row1_col6 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_f2fab_row1_col7 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_f2fab_row1_col8 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_f2fab_row2_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_f2fab_row2_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_f2fab_row2_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_f2fab_row2_col3, #T_f2fab_row2_col4, #T_f2fab_row5_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_f2fab_row2_col5, #T_f2fab_row14_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_f2fab_row2_col6 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_f2fab_row2_col7 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_f2fab_row2_col8 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_f2fab_row3_col0, #T_f2fab_row3_col1, #T_f2fab_row3_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_f2fab_row3_col3, #T_f2fab_row3_col4, #T_f2fab_row3_col5, #T_f2fab_row12_col5 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_f2fab_row3_col6, #T_f2fab_row3_col7 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_f2fab_row3_col8 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_f2fab_row4_col2, #T_f2fab_row4_col5, #T_f2fab_row4_col8, #T_f2fab_row17_col0, #T_f2fab_row17_col3, #T_f2fab_row17_col6, #T_f2fab_row18_col0, #T_f2fab_row18_col1, #T_f2fab_row18_col2, #T_f2fab_row18_col3, #T_f2fab_row18_col4, #T_f2fab_row18_col5, #T_f2fab_row18_col6, #T_f2fab_row18_col7, #T_f2fab_row18_col8, #T_f2fab_row19_col0, #T_f2fab_row19_col1, #T_f2fab_row19_col2, #T_f2fab_row19_col3, #T_f2fab_row19_col4, #T_f2fab_row19_col5, #T_f2fab_row19_col6, #T_f2fab_row19_col7, #T_f2fab_row19_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f2fab_row4_col3, #T_f2fab_row4_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_f2fab_row4_col6, #T_f2fab_row4_col7 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_f2fab_row5_col1, #T_f2fab_row6_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_f2fab_row5_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_f2fab_row5_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_f2fab_row5_col4, #T_f2fab_row9_col8 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_f2fab_row5_col6 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_f2fab_row5_col7 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_f2fab_row5_col8, #T_f2fab_row8_col3, #T_f2fab_row8_col4, #T_f2fab_row8_col5 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_f2fab_row6_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_f2fab_row6_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_f2fab_row6_col4 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_f2fab_row6_col5, #T_f2fab_row11_col6, #T_f2fab_row11_col7, #T_f2fab_row11_col8, #T_f2fab_row17_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_f2fab_row6_col6, #T_f2fab_row6_col7 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_f2fab_row6_col8, #T_f2fab_row10_col6, #T_f2fab_row10_col8, #T_f2fab_row17_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f2fab_row7_col0, #T_f2fab_row7_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_f2fab_row7_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_f2fab_row7_col3, #T_f2fab_row7_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_f2fab_row7_col5 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_f2fab_row7_col8 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_f2fab_row8_col0, #T_f2fab_row8_col1, #T_f2fab_row8_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_f2fab_row8_col6, #T_f2fab_row8_col7 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_f2fab_row8_col8 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_f2fab_row9_col0, #T_f2fab_row9_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_f2fab_row9_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_f2fab_row9_col3, #T_f2fab_row9_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_f2fab_row9_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_f2fab_row9_col6, #T_f2fab_row9_col7 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f2fab_row10_col0, #T_f2fab_row10_col1, #T_f2fab_row12_col6, #T_f2fab_row12_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_f2fab_row10_col7, #T_f2fab_row17_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_f2fab_row11_col3, #T_f2fab_row11_col4, #T_f2fab_row11_col5, #T_f2fab_row13_col3, #T_f2fab_row13_col4, #T_f2fab_row15_col3, #T_f2fab_row16_col0, #T_f2fab_row16_col5, #T_f2fab_row16_col7, #T_f2fab_row16_col8 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_f2fab_row12_col3, #T_f2fab_row12_col4, #T_f2fab_row13_col0, #T_f2fab_row13_col1, #T_f2fab_row14_col1, #T_f2fab_row14_col7 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_f2fab_row12_col8 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_f2fab_row13_col5, #T_f2fab_row15_col7, #T_f2fab_row16_col1, #T_f2fab_row16_col2, #T_f2fab_row17_col5 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_f2fab_row13_col6, #T_f2fab_row13_col7, #T_f2fab_row15_col1, #T_f2fab_row17_col4 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f2fab_row13_col8, #T_f2fab_row14_col0, #T_f2fab_row14_col6 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_f2fab_row14_col3, #T_f2fab_row14_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f2fab_row14_col5 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_f2fab_row14_col8 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_f2fab_row15_col0, #T_f2fab_row15_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f2fab_row15_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_f2fab_row15_col4, #T_f2fab_row16_col3, #T_f2fab_row16_col4, #T_f2fab_row16_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f2fab_row15_col5 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_f2fab_row15_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f2fab_level0_row0, #T_f2fab_level0_row5, #T_f2fab_level0_row6 {
#   color: crimson;
# }
# #T_f2fab_level0_row1, #T_f2fab_level0_row2, #T_f2fab_level0_row3, #T_f2fab_level0_row7, #T_f2fab_level0_row12, #T_f2fab_level0_row14, #T_f2fab_level0_row15, #T_f2fab_level0_row19 {
#   color: black;
# }
# #T_f2fab_level0_row4 {
#   color: darkorange;
# }
# #T_f2fab_level0_row8, #T_f2fab_level0_row11, #T_f2fab_level0_row18 {
#   color: dodgerblue;
# }
# #T_f2fab_level0_row9, #T_f2fab_level0_row10, #T_f2fab_level0_row13, #T_f2fab_level0_row16, #T_f2fab_level0_row17 {
#   color: mediumseagreen;
# }
# </style>
# <table id="T_f2fab" style="font-size: 12px">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2fab_level0_col0" class="col_heading level0 col0" colspan="3"></th>
#       <th id="T_f2

# %% [markdown]
# When sorting after the linearly scaled edge betweenness for restricted paths, we see
# mostly sparsified nodes at the top.

# %%
display(pd.DataFrame({
    ("", "C_B_e"): cb["Edge"], ("", "C_B_e_paths"): cb_paths["Edge"],
    ("", "C_B_e_restr"): cb_restr["Edge"],
    ("Len scales", "C_B_e"): cb["Edge_len"],
    ("Len scales", "C_B_e_paths"): cb_paths["Edge_len"],
    ("Len scales", "C_B_e_restr"): cb_restr["Edge_len"],
    ("Lin scales", "C_B_e"): cb["Edge_lin"],
    ("Lin scales", "C_B_e_paths"): cb_paths["Edge_lin"],
    ("Lin scales", "C_B_e_restr"): cb_restr["Edge_lin"]
}
).sort_values(by=[("Lin scales", "C_B_e_restr")], ascending=False)
        .style.background_gradient(cmap="Blues", axis=None)
        .format(precision=3)
        .map_index(lambda x: f"color: {G.nodes[x]['partition']}" if x in G
                   .nodes else ""). \
        set_table_attributes('style="font-size: 12px"'),
        )
# Out:
# <style type="text/css">
# #T_8473d_row0_col0, #T_8473d_row4_col0, #T_8473d_row4_col1, #T_8473d_row4_col3, #T_8473d_row4_col4, #T_8473d_row9_col4, #T_8473d_row14_col0, #T_8473d_row14_col1, #T_8473d_row14_col3, #T_8473d_row14_col4, #T_8473d_row23_col4, #T_8473d_row25_col3, #T_8473d_row25_col4, #T_8473d_row25_col5, #T_8473d_row26_col2, #T_8473d_row26_col5, #T_8473d_row29_col2, #T_8473d_row29_col5, #T_8473d_row32_col0, #T_8473d_row32_col1, #T_8473d_row32_col3, #T_8473d_row32_col4, #T_8473d_row36_col2, #T_8473d_row36_col8, #T_8473d_row40_col0, #T_8473d_row40_col6, #T_8473d_row41_col0, #T_8473d_row44_col2, #T_8473d_row47_col0, #T_8473d_row47_col1, #T_8473d_row47_col3, #T_8473d_row47_col4, #T_8473d_row47_col6, #T_8473d_row47_col7, #T_8473d_row50_col0, #T_8473d_row50_col1, #T_8473d_row50_col6, #T_8473d_row50_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8473d_row0_col1, #T_8473d_row1_col6, #T_8473d_row2_col6, #T_8473d_row2_col7, #T_8473d_row9_col1, #T_8473d_row16_col3, #T_8473d_row16_col4, #T_8473d_row33_col0, #T_8473d_row33_col1, #T_8473d_row33_col2, #T_8473d_row33_col3, #T_8473d_row33_col6, #T_8473d_row33_col7, #T_8473d_row33_col8, #T_8473d_row43_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_8473d_row0_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_8473d_row0_col3, #T_8473d_row9_col3, #T_8473d_row23_col5, #T_8473d_row38_col8, #T_8473d_row39_col0, #T_8473d_row39_col1, #T_8473d_row39_col6, #T_8473d_row41_col3, #T_8473d_row41_col4, #T_8473d_row49_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8473d_row0_col4, #T_8473d_row1_col1, #T_8473d_row1_col4, #T_8473d_row1_col7, #T_8473d_row2_col0, #T_8473d_row2_col1, #T_8473d_row2_col3, #T_8473d_row2_col4, #T_8473d_row5_col6, #T_8473d_row10_col0, #T_8473d_row10_col1, #T_8473d_row37_col2, #T_8473d_row37_col5, #T_8473d_row37_col8, #T_8473d_row40_col3, #T_8473d_row41_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8473d_row0_col5, #T_8473d_row2_col2, #T_8473d_row10_col2, #T_8473d_row37_col0, #T_8473d_row37_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_8473d_row0_col6, #T_8473d_row1_col0, #T_8473d_row1_col3, #T_8473d_row27_col0, #T_8473d_row27_col1, #T_8473d_row27_col6, #T_8473d_row27_col7, #T_8473d_row32_col2, #T_8473d_row32_col5, #T_8473d_row40_col1, #T_8473d_row40_col4, #T_8473d_row41_col6, #T_8473d_row43_col0, #T_8473d_row43_col3, #T_8473d_row44_col5 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_8473d_row0_col7, #T_8473d_row6_col1, #T_8473d_row14_col6, #T_8473d_row14_col7, #T_8473d_row16_col5, #T_8473d_row23_col2, #T_8473d_row24_col2, #T_8473d_row24_col7, #T_8473d_row25_col6, #T_8473d_row25_col7, #T_8473d_row25_col8, #T_8473d_row26_col8, #T_8473d_row43_col6, #T_8473d_row52_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_8473d_row0_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8473d_row1_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_8473d_row1_col5 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_8473d_row1_col8, #T_8473d_row2_col8 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_8473d_row2_col5 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_8473d_row3_col0, #T_8473d_row3_col4, #T_8473d_row3_col6, #T_8473d_row5_col4, #T_8473d_row23_col0, #T_8473d_row23_col3, #T_8473d_row23_col6, #T_8473d_row45_col3, #T_8473d_row48_col0, #T_8473d_row48_col6, #T_8473d_row50_col5 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8473d_row3_col1, #T_8473d_row3_col7, #T_8473d_row8_col3, #T_8473d_row8_col4, #T_8473d_row45_col0, #T_8473d_row45_col4, #T_8473d_row45_col5, #T_8473d_row45_col6, #T_8473d_row46_col4, #T_8473d_row46_col5, #T_8473d_row47_col2, #T_8473d_row47_col5, #T_8473d_row47_col8, #T_8473d_row48_col1, #T_8473d_row48_col2, #T_8473d_row48_col7, #T_8473d_row48_col8, #T_8473d_row49_col8, #T_8473d_row50_col2, #T_8473d_row50_col8 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_8473d_row3_col2, #T_8473d_row5_col5 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_8473d_row3_col3, #T_8473d_row48_col3, #T_8473d_row48_col4, #T_8473d_row48_col5, #T_8473d_row51_col0, #T_8473d_row51_col1, #T_8473d_row51_col2, #T_8473d_row51_col3, #T_8473d_row51_col4, #T_8473d_row51_col5, #T_8473d_row51_col6, #T_8473d_row51_col7, #T_8473d_row51_col8 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_8473d_row3_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_8473d_row3_col8 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_8473d_row4_col2, #T_8473d_row14_col2, #T_8473d_row26_col0, #T_8473d_row26_col1, #T_8473d_row29_col0, #T_8473d_row29_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_8473d_row4_col5 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_8473d_row4_col6, #T_8473d_row4_col7, #T_8473d_row22_col2, #T_8473d_row22_col8, #T_8473d_row35_col4, #T_8473d_row35_col6 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_8473d_row4_col8 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_8473d_row5_col0, #T_8473d_row6_col3, #T_8473d_row18_col0, #T_8473d_row18_col1, #T_8473d_row18_col3, #T_8473d_row18_col4, #T_8473d_row18_col6, #T_8473d_row18_col7, #T_8473d_row39_col7, #T_8473d_row46_col0, #T_8473d_row46_col6, #T_8473d_row52_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_8473d_row5_col1, #T_8473d_row5_col7, #T_8473d_row10_col3, #T_8473d_row10_col4, #T_8473d_row27_col5, #T_8473d_row36_col5, #T_8473d_row38_col2, #T_8473d_row39_col8 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_8473d_row5_col2, #T_8473d_row13_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_8473d_row5_col3, #T_8473d_row27_col3, #T_8473d_row27_col4, #T_8473d_row40_col2, #T_8473d_row42_col5, #T_8473d_row43_col2, #T_8473d_row43_col8, #T_8473d_row44_col8, #T_8473d_row46_col1, #T_8473d_row46_col7 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8473d_row5_col8 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_8473d_row6_col0, #T_8473d_row15_col0, #T_8473d_row15_col6, #T_8473d_row22_col5, #T_8473d_row33_col4, #T_8473d_row33_col5, #T_8473d_row34_col0, #T_8473d_row34_col1, #T_8473d_row34_col2, #T_8473d_row34_col3, #T_8473d_row34_col4, #T_8473d_row34_col5, #T_8473d_row34_col6, #T_8473d_row34_col7, #T_8473d_row34_col8, #T_8473d_row40_col7, #T_8473d_row43_col4 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_8473d_row6_col2, #T_8473d_row38_col1, #T_8473d_row38_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_8473d_row6_col4, #T_8473d_row9_col0, #T_8473d_row25_col0, #T_8473d_row25_col1, #T_8473d_row25_col2, #T_8473d_row35_col8, #T_8473d_row41_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_8473d_row6_col5 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_8473d_row6_col6, #T_8473d_row11_col3, #T_8473d_row11_col4, #T_8473d_row23_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_8473d_row6_col7, #T_8473d_row21_col0, #T_8473d_row21_col1, #T_8473d_row21_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_8473d_row6_col8 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_8473d_row7_col0, #T_8473d_row7_col1, #T_8473d_row7_col2, #T_8473d_row18_col8 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_8473d_row7_col3, #T_8473d_row7_col4, #T_8473d_row36_col6 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_8473d_row7_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_8473d_row7_col6, #T_8473d_row7_col7 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_8473d_row7_col8 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_8473d_row8_col0, #T_8473d_row8_col1, #T_8473d_row8_col6, #T_8473d_row8_col7, #T_8473d_row15_col3, #T_8473d_row38_col5, #T_8473d_row39_col2, #T_8473d_row40_col8, #T_8473d_row41_col2, #T_8473d_row41_col8, #T_8473d_row42_col2, #T_8473d_row42_col8, #T_8473d_row49_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_8473d_row8_col2, #T_8473d_row20_col1, #T_8473d_row42_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_8473d_row8_col5, #T_8473d_row12_col6, #T_8473d_row12_col7 {
#   background-color: #bad6eb;
#   color:

# %% [markdown]
# For a more intuitive comparison, we can plot the betweenness values for the edges
# (and nodes) on the graph. The size of the nodes is proportional to the node betweenness
# and the color of the edges is proportional to the edge betweenness.

# %%
def betweenness_plot(G, cb, cb_e, title):
    """Plot graph with edge widths proportional to edge betweenness."""
    fig, ax = plt.subplots(figsize=(8, 5))
    pos = nx.kamada_kawai_layout(G, weight=None)
    nx.draw_networkx_nodes(
        G, pos=pos, ax=ax,
        node_color=[G.nodes[n]["partition"] for n in G.nodes],
        # linewidths=2,
        node_size=[v * 1000 + 10 for v in cb.values()],
    )
    e_col = nx.draw_networkx_edges(
        G, pos=pos, ax=ax,
        edge_color=[cb_e[(u, v)] for u, v in G.edges(keys=False)],
        edge_cmap=plt.cm.Blues,
        # alpha=0.8,
        # width=[v * 10 for v in cb_e.values()],
        connectionstyle="arc3,rad=0.1",
    )
    for col in e_col:
        col.set_zorder(2)
    # Add title
    ax.set_title(title)
    plt.show()


betweenness_plot(G, cb["Node"], cb["Edge"], "Betweenness centrality")
betweenness_plot(G, cb_paths["Node"], cb_paths["Edge"],
                 "Betweenness centrality given paths")
betweenness_plot(G, cb_restr["Node"], cb_restr["Edge"],
                 "Betweenness centrality restricted paths")

# %% [markdown]
# ## Simplify algorithm
#
# For our case of given graphs, the algorithm can be simplified, as we always only have
# one path between two nodes. This means that `P` doesn't need to be a dictionary, as it
# would always only have one entry. All outputs can be lists. We do not need `sigma` as it
# would always be 2. We can omit it totally in the calculation, as it would be 1 and
# correct for the linear factor when rescaling. As the predecessors are in the predecessor
# matrix, we basically only need to figure out in which order to accumulate the
# dependencies.

# %%
def _single_source_given_paths_simplified(dist_row):
    """Sort nodes, predecessors and distances by distance.

    Parameters
    ----------
    dist_row : np.array
        Distance row sorted non-decreasingly.

    Returns
    -------
    S : list
        List of node indices in order of distance.

    Notes
    -----
    Does not include endpoints.
    """
    dist_order = argsort(dist_row)
    try:
        # Remove unreachable indices (inf), check from back which is the first
        # reachable node
        while dist_row[dist_order[-1]] == np.inf:
            dist_order = dist_order[:-1]
        # Remove immediately reachable nodes with distance 0, including s itself
        while dist_row[dist_order[0]] == 0:
            dist_order = dist_order[1:]
    except IndexError:
        # If all nodes are unreachable, return empty list
        return []
    return list(dist_order)

# %% [markdown]
# The iteration over the nodes then becomes:

# %%
def simplified_betweenness(node_order, edge_list, dist, pred):
    """Simplified betweenness centrality calculation."""
    node_indices = list(range(len(node_order)))
    betweenness = dict.fromkeys(node_indices, 0.0)
    betweenness_len = betweenness.copy()  # Length scaled betweenness
    betweenness_lin = betweenness.copy()  # Linear scaled betweenness
    betweenness_edge = betweenness.copy()
    betweenness_edge.update(dict.fromkeys(
        [(node_order.index(u), node_order.index(v)) for u, v in edge_list],
        0.0))
    betweenness_edge_len = betweenness_edge.copy()
    betweenness_edge_lin = betweenness_edge.copy()
    # b[v]=0 for v in G and b[e]=0 for e in G.edges
    # Loop over nodes to collect betweenness using pair-wise dependencies
    for s in node_indices:
        S = _single_source_given_paths_simplified(dist[s])
        # betweenness, _ = _accumulate_basic(betweenness, S.copy(), P, sigma, s)
        # betweenness_edge = _accumulate_edges(betweenness_edge, S.copy(), P, sigma, s)
        delta = dict.fromkeys(node_indices, 0)
        delta_len = delta.copy()
        # S is 1d-ndarray, while not empty
        while S:
            w = S.pop()
            # No while loop over multiple predecessors, only one path per node pair
            v = pred[s, w]  # P[w]
            d = dist[s, w]  # D[w]
            # Calculate dependency contribution
            coeff = 1 + delta[w]
            coeff_len = (1 / d + delta[w])
            # Add edge betweenness contribution
            if (v, w) not in betweenness_edge:
                betweenness_edge[(w, v)] += coeff
                betweenness_edge_len[(w, v)] += coeff_len
                betweenness_edge_lin[(w, v)] += d * coeff_len
            else:
                betweenness_edge[(v, w)] += coeff
                betweenness_edge_len[(v, w)] += coeff_len
                betweenness_edge_lin[(v, w)] += d * coeff_len
            # Add to dependency for further nodes/loops
            delta[v] += coeff
            delta_len[v] += coeff_len
            # Add node betweenness contribution
            if w != s:
                betweenness[w] += delta[w]
                betweenness_len[w] += delta_len[w]
                betweenness_lin[w] += d * delta_len[w]
    # Normalize betweenness values and rename node index keys to ids
    scale = 1 / ((len(node_order) - 1) * (len(node_order) - 2))
    for bc_dict in [betweenness, betweenness_len, betweenness_lin]:  # u_idx -> u_id
        for v in bc_dict.keys():
            bc_dict[v] *= scale
            v = node_order[v]
    for n in node_indices:  # Remove nodes
        del betweenness_edge[n]
        del betweenness_edge_len[n]
        del betweenness_edge_lin[n]
    scale = 1 / (len(node_order) * (len(node_order) - 1))
    for bc_e_dict in [betweenness_edge, betweenness_edge_len,
                      betweenness_edge_lin]:  # (u_idx, v_idx) -> (u_id, v_id)
        for e in bc_e_dict.keys():
            bc_e_dict[e] *= scale
            e = (node_order[e[0]], node_order[e[1]])

    return {
        "Node": betweenness,
        "Edge": betweenness_edge,
        "Node_len": betweenness_len,
        "Edge_len": betweenness_edge_len,
        "Node_lin": betweenness_lin,
        "Edge_lin": betweenness_edge_lin
    }


cb_paths_2 = simplified_betweenness(node_order, G.edges(keys=False), dist, pred)
cb_restr_2 = simplified_betweenness(node_order, G.edges(keys=False), dist_restr,
                                    pred_restr)

# %%
# Check if results are the same when unsimplified
cb_paths["Edge"] == cb_paths_2["Edge"]
for k, v in cb_paths.items():
    print(
        f"{k}: {all([np.isclose(cb_paths[k][k1], cb_paths_2[k][k1]) for k1 in cb_paths[k].keys()])}")
    print(f"keys: {v.keys() == cb_paths_2[k].keys()}")
    for k1, val1 in v.items():
        val2 = cb_paths_2[k][k1]
        if not np.isclose(val1, val2):
            print(val1, val2)
# Out:
# Node: False
# keys: True
# 0.09999999999999999 0.1111111111111111
# 0.031578947368421054 0.03508771929824561
# 0.010526315789473684 0.011695906432748537
# 0.05789473684210526 0.06432748538011696
# 0.2736842105263158 0.30409356725146197
# 0.049999999999999996 0.05555555555555555
# 0.15263157894736842 0.1695906432748538
# 0.26842105263157895 0.2982456140350877
# 0.021052631578947368 0.023391812865497075
# 0.034210526315789476 0.038011695906432746
# 0.042105263157894736 0.04678362573099415
# 0.2894736842105263 0.3216374269005848
# 0.2394736842105263 0.26608187134502925
# 0.21578947368421053 0.23976608187134502
# 0.2131578947368421 0.23684210526315788
# 0.22894736842105262 0.2543859649122807
# 0.12631578947368421 0.14035087719298245
# 0.04473684210526316 0.049707602339181284
# Edge: True
# keys: True
# Node_len: False
# keys: True
# 0.07313767820943767 0.0812640868993752
# 0.008219771107034904 0.00913307900781656
# 0.0061403508771929825 0.00682261208576998
# 0.044295461952093856 0.049217179946770946
# 0.22946370816687553 0.2549596757409728
# 0.021116233284387647 0.023462481427097386
# 0.11539523149980213 0.12821692388866904
# 0.22181564165124942 0.24646182405694375
# 0.005480001421123074 0.006088890467914524
# 0.019813615507248455 0.02201512834138717
# 0.03220881150244031 0.03578756833604479
# 0.2325841273344125 0.2584268081493472
# 0.2014165967171499 0.223796218574611
# 0.19667861852237278 0.218531798358192
# 0.18006572332036724 0.20007302591151915
# 0.21724997606004473 0.24138886228893858
# 0.09276404798359016 0.10307116442621128
# 0.008966952492744458 0.009963280547493842
# Edge_len: True
# keys: True
# Node_lin: False
# keys: True
# 0.13896758494845704 0.15440842772050783
# 0.023359176261386148 0.025954640290429053
# 0.007017543859649122 0.007797270955165692
# 0.049915064363695624 0.05546118262632846
# 0.38272005205036447 0.4252445022781828
# 0.0473048193471913 0.05256091038576811
# 0.25828897902651365 0.28698775447390407
# 0.3871473764597995 0.43016375162199955
# 0.01283262944726276 0.014258477163625289
# 0.03185852410754838 0.0353983601194982
# 0.05752803060282284 0.06392003400313649
# 0.5378626268058401 0.5976251408953779
# 0.44474809271817645 0.49416454746464056
# 0.41385367319495386 0.4598374146610599
# 0.42254482067639965 0.4694942451959995
# 0.35204737799703467 0.39116375333003855
# 0.24752834967722848 0.27503149964136503
# 0.0357698896125187 0.039744321791687444
# Edge_lin: True
# keys: True

# %% [markdown]
# ## Performance comparison
#
# We compare the performance of the simplified and the original betweenness centrality
# calculation.

# %%
# %timeit calculate_betweenness_with(_single_source_dijkstra_path_basic, "weight", show_tree=False)
# %timeit calculate_betweenness_with(_single_source_given_paths_basic, node_order, pred, dist, show_tree=False)
# %timeit simplified_betweenness(node_order, G.edges(keys=False), dist, pred)
# Out:
# 1.06 ms ± 11.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 530 µs ± 4.78 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 460 µs ± 10.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# On the first look, the simplified version is not faster, this is because the
# example graph is too small. But for larger graphs the implemented function
# [{py:func}`betweenness_centrality()`](betweenness_centrality_impl) is orders of
# magnitude faster.
#
# In the [Implementation](#implementation) we also use arrays for the betweenness and
# dependency values $\delta$, which is more efficient than dictionaries. For
# acceleration, we also use the {external+numba:mod}`numba` package to compile the
# functions to machine code. {external+numba:mod}`numba` provides the
# {external+numba:func}`njit` decorator, which can be used to pre-compile functions and
# easy parallelization.
#
# ### Real world example
#
# To compare further we use a real city, not especially large, but large enough for us
# to see a difference.

# %%
part.graph
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[16], line 1
#
# ----> 1 part.graph
#
#
#
# AttributeError: 'dict' object has no attribute 'graph'

# %%
from superblockify import ResidentialPartitioner
from superblockify.config import Config

CITY_NAME, SEARCH_STR = Config.PLACES_SMALL[1]
part = ResidentialPartitioner(
    name=CITY_NAME + "_main", city_name=CITY_NAME, search_str=SEARCH_STR, unit="time"
)
part.run(calculate_metrics=False)

# Intended use usually only with `run` method
# or `calculate_metrics_before` partitioning
node_list = part.get_sorted_node_list()
# Out:
# 2026-03-23 11:00:13,214 |     INFO | tessellation.py:101 | Calculating edge cells for graph with 1256 edges.
# 2026-03-23 11:00:14,136 |     INFO | tessellation.py:155 | Tessellated 785 edge cells in 0:00:00.
# 2026-03-23 11:00:14,299 |     INFO | ghsl.py:129 | Using the GHSL raster tiles for the bounding box (10529206.185883993, 3665258.196608499, 10534037.079623077, 3670687.995752596).
# 2026-03-23 11:00:16,355 |  WARNING | features.py:148 | CPLE_AppDefined in DeprecationWarning: 'Memory' driver is deprecated since GDAL 3.11. Use 'MEM' onwards. Further messages of this type will be suppressed.
# Distributing population over road cells:  67%|██████▋   | 1570/2355 [00:04<00:02, 346.34Cells/s]
# 2026-03-23 11:00:21,004 |     INFO | __init__.py:11 | superblockify version 1.0.2
# 2026-03-23 11:00:21,004 |     INFO | __init__.py:11 | superblockify version 1.0.2
# 2026-03-23 11:00:21,272 |     INFO | utils.py:265 | Highway counts (type, count, proportion):
#                              count  proportion
# highway
# residential                    711    0.572003
# tertiary                       184    0.148029
# primary                        132    0.106195
# secondary                      122    0.098150
# unclassified                    45    0.036203
# living_street                   18    0.014481
# primary_link                    10    0.008045
# secondary_link                   9    0.007241
# tertiary_link                    8    0.006436
# [tertiary, unclassified]         2    0.001609
# [residential, unclassified]      1    0.000805
# [unclassified, residential]      1    0.000805
# 2026-03-23 11:00:21,273 |     INFO | utils.py:299 | Graph stats:
#                                              0
# Number of nodes                            539
# Number of edges                           1256
# Average degree                        4.660482
# Circuity average                      1.099485
# Street orientation order              0.306443
# Date created               2026-03-23 11:00:12
# Projection                          EPSG:32650
# Area by OSM boundary (m²)      18634010.566506
# 2026-03-23 11:00:21,274 |     INFO | base.py:185 | Initialized MissionTown_main(ResidentialPartitioner) with 532 nodes and 1243 edges.
# 2026-03-23 11:00:21,398 |     INFO | checks.py:86 | The partitioning MissionTown_main is valid.

# %%
from superblockify.metrics.measures import betweenness_centrality
from superblockify.metrics.distances import calculate_path_distance_matrix
# %timeit betweenness_centrality(part.graph, node_list, *calculate_path_distance_matrix(part.graph, weight = "travel_time", node_order = node_list), weight="travel_time")
# %timeit nx.betweenness_centrality(part.graph, weight="travel_time")
# Out:
# 36.5 ms ± 2.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 722 ms ± 15.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# The code scales with the number of nodes and number of edges. As in real world cities
# the edges do not scale with the number of nodes, the runtime is well bearable for
# simplified graphs of metropolitan cities.
#
# ## Implementation
#
# (betweenness_centrality_impl)=
# ```{eval-rst}
# .. autofunction:: superblockify.metrics.measures.betweenness_centrality
#     :noindex:
# ```
#
# ```{eval-rst}
# .. autofunction:: superblockify.metrics.measures.__accumulate_bc
#     :noindex:
# ```
